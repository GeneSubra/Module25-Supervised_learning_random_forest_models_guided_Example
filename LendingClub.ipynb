# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ##### df = pd.read_csv(
#     'https://www.dropbox.com/s/0so14yudedjmm5m/LoanStats3d.csv?dl=1',
#     skipinitialspace=True,
#     header=1)
# ### Note the warning about dtypes.

# %%
df = pd.read_csv('LoanStats3d_1.csv')
# Note the warning about dtypes.
# Out:
# c:\python\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68009401   72868139      16000        16000            16000   60 months
# 1  68354783   73244544       9600         9600             9600   36 months
# 2  68466916   73356753      25000        25000            25000   36 months
# 3  68466961   73356799      28000        28000            28000   36 months
# 4  68495092   73384866       8650         8650             8650   36 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   14.85%       379.39     C        C5  ...                  0
# 1    7.49%       298.58     A        A4  ...                  0
# 2    7.49%       777.55     A        A4  ...                  0
# 3    6.49%       858.05     A        A2  ...                  0
# 4   19.89%       320.99     E        E3  ...                  0
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# ...

# %%
df.tail()
# Out:
#              id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 69856  63938532   68369299      20000        20000            19900
# 69857  64210965   68680697      35000        35000            35000
# 69858  64391234   68860973       9675         9675             9675
# 69859  64291190   68760930       4000         4000             4000
# 69860  37000204   39752931      14675        14675            14675
#
#              term int_rate  installment grade sub_grade  ...  \
# 69856   60 months   12.59%       450.88     C        C2  ...
# 69857   60 months   17.57%       880.61     D        D4  ...
# 69858   36 months   13.67%       329.12     C        C4  ...
# 69859   36 months    9.99%       129.05     B        B3  ...
# 69860   36 months   19.99%       545.31     E        E3  ...
#
#       num_tl_90g_dpd_24m num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75  \
# 69856                  0                  4          100.0              50.0
# ...

# %%
df.dtypes
# Out:
# id                            int64
# member_id                     int64
# loan_amnt                     int64
# funded_amnt                   int64
# funded_amnt_inv               int64
#                               ...
# tax_liens                     int64
# tot_hi_cred_lim               int64
# total_bal_ex_mort             int64
# total_bc_limit                int64
# total_il_high_credit_limit    int64
# Length: 111, dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of              id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      68009401   72868139      16000        16000            16000
# 1      68354783   73244544       9600         9600             9600
# 2      68466916   73356753      25000        25000            25000
# 3      68466961   73356799      28000        28000            28000
# 4      68495092   73384866       8650         8650             8650
# ...         ...        ...        ...          ...              ...
# 69856  63938532   68369299      20000        20000            19900
# 69857  64210965   68680697      35000        35000            35000
# 69858  64391234   68860973       9675         9675             9675
# 69859  64291190   68760930       4000         4000             4000
# 69860  37000204   39752931      14675        14675            14675
#
#              term int_rate  installment grade sub_grade  ...  \
# ...

# %%
df.shape
# Out:
# (69861, 111)

# %%
df.loan_status
# Out:
# 0           Current
# 1           Current
# 2        Fully Paid
# 3           Current
# 4        Fully Paid
#             ...
# 69856       Current
# 69857       Current
# 69858       Current
# 69859       Current
# 69860       Current
# Name: loan_status, Length: 69861, dtype: object

# %%
from sklearn import ensemble
from sklearn.model_selection import cross_val_score

rfc = ensemble.RandomForestClassifier()
X = df.drop('loan_status', 1)
Y = df['loan_status']
X = pd.get_dummies(X)

cross_val_score(rfc, X, Y, cv=5)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-8-1c3e57bc1a47> in <module>
#       5 X = df.drop('loan_status', 1)
#       6 Y = df['loan_status']
# ----> 7 X = pd.get_dummies(X)
#       8
#       9 cross_val_score(rfc, X, Y, cv=5)
#
# c:\python\lib\site-packages\pandas\core\reshape\reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     919                 sparse=sparse,
#     920                 drop_first=drop_first,
# --> 921                 dtype=dtype,
#     922             )
#     923             with_dummies.append(dummy)
#
# c:\python\lib\site-packages\pandas\core\reshape\reshape.py in _get_dummies_1d(data, prefix, prefix_sep, dummy_na, sparse, drop_first, dtype)
#    1032
#    1033     else:
# -> 1034         dummy_mat = np.eye(number_of_cols, dtype=dtype).take(codes, axis=0)
#    1035
# ...

# %%
# The naive aproach above causing the kernel to die. Let's do some data cleaning

# %%
categorical = df.select_dtypes(include=['object'])
for i in categorical:
    column = categorical[i]
    print(i)
    print(column.nunique())
# Out:
# term
# 2
# int_rate
# 70
# grade
# 7
# sub_grade
# 35
# emp_title
# 27961
# emp_length
# 11
# home_ownership
# 4
# verification_status
# 3
# issue_d
# 3
# loan_status
# 7
# pymnt_plan
# 1
# url
# 69861
# desc
# 6
# purpose
# 12
# title
# 12
# zip_code
# 865
# addr_state
# 49
# earliest_cr_line
# 610
# revol_util
# 1101
# initial_list_status
# 2
# last_pymnt_d
# 15
# next_pymnt_d
# 3
# last_credit_pull_d
# 15
# application_type
# 2
# verification_status_joint
# 3

# %%
# We have a problem here (above). To many distinct trpes. Let's drop the ones with over 30 unique values and 
# converting to numeric where it makes sense. 
# dates will be dropped.

# %%
# Convert ID and Interest Rate to numeric.
df['id'] = pd.to_numeric(df['id'], errors='coerce')
df['int_rate'] = pd.to_numeric(df['int_rate'].str.strip('%'), errors='coerce')

# Drop other columns with many unique variables
df.drop(['url', 'emp_title', 'zip_code', 'earliest_cr_line', 'revol_util',
            'sub_grade', 'addr_state', 'desc'], 1, inplace=True)

# %%
pd.get_dummies(df)
# Out:
#              id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  int_rate  \
# 0      68009401   72868139      16000        16000            16000     14.85
# 1      68354783   73244544       9600         9600             9600      7.49
# 2      68466916   73356753      25000        25000            25000      7.49
# 3      68466961   73356799      28000        28000            28000      6.49
# 4      68495092   73384866       8650         8650             8650     19.89
# ...         ...        ...        ...          ...              ...       ...
# 69856  63938532   68369299      20000        20000            19900     12.59
# 69857  64210965   68680697      35000        35000            35000     17.57
# 69858  64391234   68860973       9675         9675             9675     13.67
# 69859  64291190   68760930       4000         4000             4000      9.99
# 69860  37000204   39752931      14675        14675            14675     19.99
#
# ...

# %%
# Now it works, but we sacrifice several features. 
# If you want to include them you could run the dummies independently and then append them back to the dataframe.

# %%
from sklearn import ensemble
from sklearn.model_selection import cross_val_score

rfc = ensemble.RandomForestClassifier()
X = df.drop('loan_status', 1)
Y = df['loan_status']
X = pd.get_dummies(X)
X = X.dropna(axis=1)

cross_val_score(rfc, X, Y, cv=10)
# Out:
# c:\python\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\python\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\python\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\python\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ...

# %%
# The score cross validation reports is the accuracy of the tree. Here we're about 98% accurate.

# %% [markdown]
# ##### That works pretty well, but there are a few potential problems. Firstly, we didn't really do much in the way of feature selection or model refinement. As such there are a lot of features in there that we don't really need. Some of them are actually quite impressively useless.
#
# ##### There's also some variance in the scores. The fact that one gave us only 93% accuracy while others gave higher than 98 is concerning. This variance could be corrected by increasing the number of estimators. That will make it take even longer to run, however, and it is already quite slow.

# %%
from sklearn import ensemble
from sklearn.model_selection import cross_val_score

rfc = ensemble.RandomForestClassifier()
X = df.drop('loan_status', 1)
Y = df['loan_status']
X = pd.get_dummies(X)
X = X.dropna(axis=1)

cross_val_score(rfc, X, Y, cv=20)
# Out:
# c:\python\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\python\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\python\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# c:\python\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ...

# %%
# increasing the cross validation reduced the accuracy gap to 0.0052
